# %% [markdown]
# ## **Video URL and description**
#
# #### Video URL: https://www.tiktok.com/@smartypantsshow/video/7385725664462212394?_r=1&_t=ZS-91IHlhn3sDy
#
# ### Description:
#
#
#
# ## **Research Question (this should be clearly scoped):**
# Are commenters generally accepting of the premise that water is wet
#
#
# ## Concepts (this can be a matrix or in paragraph style) and a description of how they changed with coding
# Concept 1: Commenter is supportive of the premise that water is wet
# Concept 2: Commenter is generally in disagreement with the premise that water is wet
#
# ## Your final LLM prompt and Inter-Rater Reliability scores
#
# ## A brief reflection on how you changed your prompting strategies to achieve better inter-rater reliability scores
#
# ## 1-3 charts or graphs that answer your research question
#
# ## A 2-3 paragraph write up reporting your results and answering your research question
